# %% [markdown]
# <td>
#    <a target="_blank" href="https://www.clarifai.com/" ><img src="https://upload.wikimedia.org/wikipedia/commons/b/bc/Clarifai_Logo_FC_Web.png" width=256/></a>
# </td>

# %% [markdown]
# # Using PostgreSQL Database with Langchain

# %% [markdown]
# ## Requirements

# %%
# !pip install clarifai psycopg2 langchain  langchain-experimental

# %%
import os
os.environ["CLARIFAI_PAT"]="PAT" # Replace with your PAT token.

# %% [markdown]
# *Note: Guide to get your [PAT](https://docs.clarifai.com/clarifai-basics/authentication/personal-access-tokens)*

# %% [markdown]
# ## Settting Up Database

# %% [markdown]
# For this example we will be using a dvd rental database. PostgreSQL  allows users to load a prebuilt database into the server. Follow this [link](https://www.geeksforgeeks.org/postgresql-loading-a-database/?ref=lbp) to know more about the database.

# %% [markdown]
# Once the database has been loaded we can setup a connection with the server using the following code,

# %%
import psycopg2
# Establish a connection to the PostgreSQL database
conn = psycopg2.connect(
    host='localhost',
    port=5432, # replace with your PORT
    user='postgres', # replace with your username
    password='root', # replace with your password
    database='dvdrental'
)

# Create a cursor object to execute SQL commands
cursor = conn.cursor()


conn.close()

# %% [markdown]
# The SQLDatabase feature from Langchain allows LLM's  to run queries on the above PostgreSQL Database.

# %%
# Creating a SQLDatabase instance by connecting to a PostgreSQL database
# The URI specifies the necessary connection details such as the database type (PostgreSQL),
# username (postgres), password (root), host (localhost), port (5432), and database name (dvdrental).
db = SQLDatabase.from_uri(
    f"postgresql+psycopg2://postgres:root@localhost:5432/dvdrental",
)

# %% [markdown]
# ## Model Initialisation

# %% [markdown]
# For our task we are going to choose GPT-4-Turbo as it was fast and accurate and can handle big prompts.

# %%
MODEL_URL="https://clarifai.com/openai/chat-completion/models/gpt-4-turbo"

# %%
from langchain.llms import Clarifai
llm=Clarifai(model_url=MODEL_URL) # using GPT-4-Turbo from Clarifai platform

# %%
from langchain.globals import set_debug
set_debug(True) # Displays outputs in all steps which leads to easy debugging

# %% [markdown]
# ## Running Queries on PostgreSQL Database

# %%
from langchain_experimental.sql import SQLDatabaseChain

# %% [markdown]
# The below prompt instructs the model on how to present the query results,

# %%
PROMPT="""
You are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:

1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.
2)Execute the query and return the results to answer the input question.
3)Ensure that the query selects only the required columns from the relevant tables.
5)Utilize only the column names present in the provided tables.
6)Avoid querying for columns that do not exist.
7) If the question involves "today", use the CURRENT_DATE function to get the current date.
8) Order the results to return the most informative data in the database.
9) Dont add code blocks for sql query
10) Please adhere to the following format while giving outputs:

Important! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error

SQL Query code  with final answer from database

{question}
"""

# %%
db_chain = SQLDatabaseChain.from_llm(llm=llm, db=db) # initialise SQLDatabase chain

# %%
question = "give me the name of customers?" 
result=db_chain.run(PROMPT.format(question=question))
# Out:
# [chain/start] [1:chain:SQLDatabaseChain] Entering Chain run with input:
# {
#   "query": "\nYou are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:\n\n1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.\n2)Execute the query and return the results to answer the input question.\n3)Ensure that the query selects only the required columns from the relevant tables.\n5)Utilize only the column names present in the provided tables.\n6)Avoid querying for columns that do not exist.\n7) If the question involves \"today\", use the CURRENT_DATE function to get the current date.\n8) Order the results to return the most informative data in the database.\n9) Dont add code blocks for sql query\n10) Please adhere to the following format while giving outputs:\n\nImportant! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error\n\nSQL Query code  with final answer from database\n\ngive me the name of customers?\n"
# }
# [chain/start] [1:chain:SQLDatabaseChain > 2:chain:LLMChain] Entering Chain run with input:
# {
#   "input": "\nYou are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:\n\n1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.\n2)Execute the query and return the results to answer the input question.\n3)Ensure that the query selects only the required columns from the relevant tables.\n5)Utilize only the column names present in the provided tables.\n6)Avoid querying for columns that do not exist.\n7) If the question involves \"today\", use the CURRENT_DATE function to get the current date.\n8) Order the results to return the most informative data in the database.\n9) Dont add code blocks for sql query\n10) Please adhere to the following format while giving outputs:\n\nImportant! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error\n\nSQL Query code  with final answer from database\n\ngive me the name of customers?\n\nSQLQuery:",
#   "top_k": "5",
#   "dialect": "postgresql",
#   "table_info": "\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now(), \n\tactive INTEGER, \n\tCONSTRAINT customer_pkey PRIMARY KEY (customer_id), \n\tCONSTRAINT customer_address_id_fkey FOREIGN KEY(address_id) REFERENCES address (address_id) ON DELETE RESTRICT ON UPDATE CASCADE\n)\n\n/*\n3 rows from customer table:\ncustomer_id\tstore_id\tfirst_name\tlast_name\temail\taddress_id\tactivebool\tcreate_date\tlast_update\tactive\n524\t1\tJared\tEly\tjared.ely@sakilacustomer.org\t530\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n1\t1\tMary\tSmith\tmary.smith@sakilacustomer.org\t5\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n2\t1\tPatricia\tJohnson\tpatricia.johnson@sakilacustomer.org\t6\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n*/\n\n\nCREATE TABLE film (\n\tfilm_id SERIAL NOT NULL, \n\ttitle VARCHAR(255) NOT NULL, \n\tdescription TEXT, \n\trelease_year INTEGER, \n\tlanguage_id SMALLINT NOT NULL, \n\trental_duration SMALLINT DEFAULT 3 NOT NULL, \n\trental_rate NUMERIC(4, 2) DEFAULT 4.99 NOT NULL, \n\tlength SMALLINT, \n\treplacement_cost NUMERIC(5, 2) DEFAULT 19.99 NOT NULL, \n\trating mpaa_ ...
#   "stop": [
#     "\nSQLResult:"
#   ]
# }
# [llm/start] [1:chain:SQLDatabaseChain > 2:chain:LLMChain > 3:llm:Clarifai] Entering LLM run with input:
# {
#   "prompts": [
#     "You are a PostgreSQL expert. Given an input question, first create a syntactically correct PostgreSQL query to run, then look at the results of the query and return the answer to the input question.\nUnless the user specifies in the question a specific number of examples to obtain, query for at most 5 results using the LIMIT clause as per PostgreSQL. You can order the results to return the most informative data in the database.\nNever query for all columns from a table. You must query only the columns that are needed to answer the question. Wrap each column name in double quotes (\") to denote them as delimited identifiers.\nPay attention to use only the column names you can see in the tables below. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which table.\nPay attention to use CURRENT_DATE function to get the current date, if the question involves \"today\".\n\nUse the following format:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use the following tables:\n\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update ...
#   ]
# }
# [llm/end] [1:chain:SQLDatabaseChain > 2:chain:LLMChain > 3:llm:Clarifai] [14.31s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "SQLQuery: SELECT \"first_name\", \"last_name\" FROM customer LIMIT 5;",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/end] [1:chain:SQLDatabaseChain > 2:chain:LLMChain] [14.32s] Exiting Chain run with output:
# {
#   "text": "SQLQuery: SELECT \"first_name\", \"last_name\" FROM customer LIMIT 5;"
# }
# [chain/start] [1:chain:SQLDatabaseChain > 4:chain:LLMChain] Entering Chain run with input:
# {
#   "input": "\nYou are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:\n\n1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.\n2)Execute the query and return the results to answer the input question.\n3)Ensure that the query selects only the required columns from the relevant tables.\n5)Utilize only the column names present in the provided tables.\n6)Avoid querying for columns that do not exist.\n7) If the question involves \"today\", use the CURRENT_DATE function to get the current date.\n8) Order the results to return the most informative data in the database.\n9) Dont add code blocks for sql query\n10) Please adhere to the following format while giving outputs:\n\nImportant! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error\n\nSQL Query code  with final answer from database\n\ngive me the name of customers?\n\nSQLQuery:SELECT \"first_name\", \"last_name\" FROM customer LIMIT 5;\nSQLResult: [('Jared', 'Ely'), ('Mary', 'Smith'), ('Patricia', 'Johnson'), ('Linda', 'Williams'), ('Barbara', 'Jones')]\nAnswer:",
#   "top_k": "5",
#   "dialect": "postgresql",
#   "table_info": "\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now(), \n\tactive INTEGER, \n\tCONSTRAINT customer_pkey PRIMARY KEY (customer_id), \n\tCONSTRAINT customer_address_id_fkey FOREIGN KEY(address_id) REFERENCES address (address_id) ON DELETE RESTRICT ON UPDATE CASCADE\n)\n\n/*\n3 rows from customer table:\ncustomer_id\tstore_id\tfirst_name\tlast_name\temail\taddress_id\tactivebool\tcreate_date\tlast_update\tactive\n524\t1\tJared\tEly\tjared.ely@sakilacustomer.org\t530\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n1\t1\tMary\tSmith\tmary.smith@sakilacustomer.org\t5\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n2\t1\tPatricia\tJohnson\tpatricia.johnson@sakilacustomer.org\t6\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n*/\n\n\nCREATE TABLE film (\n\tfilm_id SERIAL NOT NULL, \n\ttitle VARCHAR(255) NOT NULL, \n\tdescription TEXT, \n\trelease_year INTEGER, \n\tlanguage_id SMALLINT NOT NULL, \n\trental_duration SMALLINT DEFAULT 3 NOT NULL, \n\trental_rate NUMERIC(4, 2) DEFAULT 4.99 NOT NULL, \n\tlength SMALLINT, \n\treplacement_cost NUMERIC(5, 2) DEFAULT 19.99 NOT NULL, \n\trating mpaa_ ...
#   "stop": [
#     "\nSQLResult:"
#   ]
# }
# [llm/start] [1:chain:SQLDatabaseChain > 4:chain:LLMChain > 5:llm:Clarifai] Entering LLM run with input:
# {
#   "prompts": [
#     "You are a PostgreSQL expert. Given an input question, first create a syntactically correct PostgreSQL query to run, then look at the results of the query and return the answer to the input question.\nUnless the user specifies in the question a specific number of examples to obtain, query for at most 5 results using the LIMIT clause as per PostgreSQL. You can order the results to return the most informative data in the database.\nNever query for all columns from a table. You must query only the columns that are needed to answer the question. Wrap each column name in double quotes (\") to denote them as delimited identifiers.\nPay attention to use only the column names you can see in the tables below. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which table.\nPay attention to use CURRENT_DATE function to get the current date, if the question involves \"today\".\n\nUse the following format:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use the following tables:\n\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update ...
#   ]
# }
# [llm/end] [1:chain:SQLDatabaseChain > 4:chain:LLMChain > 5:llm:Clarifai] [4.52s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The names of the customers are Jared Ely, Mary Smith, Patricia Johnson, Linda Williams, and Barbara Jones.",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/end] [1:chain:SQLDatabaseChain > 4:chain:LLMChain] [4.52s] Exiting Chain run with output:
# {
#   "text": "The names of the customers are Jared Ely, Mary Smith, Patricia Johnson, Linda Williams, and Barbara Jones."
# }
# [chain/end] [1:chain:SQLDatabaseChain] [18.95s] Exiting Chain run with output:
# {
#   "result": "The names of the customers are Jared Ely, Mary Smith, Patricia Johnson, Linda Williams, and Barbara Jones."
# }

# %%
question = "give me the first name  and emails of customers?" 
# use db_chain.run(question) instead if you don't have a prompt
result=db_chain.run(PROMPT.format(question=question))
# Out:
# [chain/start] [1:chain:SQLDatabaseChain] Entering Chain run with input:
# {
#   "query": "\nYou are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:\n\n1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.\n2)Execute the query and return the results to answer the input question.\n3)Ensure that the query selects only the required columns from the relevant tables.\n5)Utilize only the column names present in the provided tables.\n6)Avoid querying for columns that do not exist.\n7) If the question involves \"today\", use the CURRENT_DATE function to get the current date.\n8) Order the results to return the most informative data in the database.\n9) Dont add code blocks for sql query\n10) Please adhere to the following format while giving outputs:\n\nImportant! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error\n\nSQL Query code  with final answer from database\n\ngive me the first name  and emails of customers?\n"
# }
# [chain/start] [1:chain:SQLDatabaseChain > 2:chain:LLMChain] Entering Chain run with input:
# {
#   "input": "\nYou are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:\n\n1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.\n2)Execute the query and return the results to answer the input question.\n3)Ensure that the query selects only the required columns from the relevant tables.\n5)Utilize only the column names present in the provided tables.\n6)Avoid querying for columns that do not exist.\n7) If the question involves \"today\", use the CURRENT_DATE function to get the current date.\n8) Order the results to return the most informative data in the database.\n9) Dont add code blocks for sql query\n10) Please adhere to the following format while giving outputs:\n\nImportant! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error\n\nSQL Query code  with final answer from database\n\ngive me the first name  and emails of customers?\n\nSQLQuery:",
#   "top_k": "5",
#   "dialect": "postgresql",
#   "table_info": "\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now(), \n\tactive INTEGER, \n\tCONSTRAINT customer_pkey PRIMARY KEY (customer_id), \n\tCONSTRAINT customer_address_id_fkey FOREIGN KEY(address_id) REFERENCES address (address_id) ON DELETE RESTRICT ON UPDATE CASCADE\n)\n\n/*\n3 rows from customer table:\ncustomer_id\tstore_id\tfirst_name\tlast_name\temail\taddress_id\tactivebool\tcreate_date\tlast_update\tactive\n524\t1\tJared\tEly\tjared.ely@sakilacustomer.org\t530\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n1\t1\tMary\tSmith\tmary.smith@sakilacustomer.org\t5\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n2\t1\tPatricia\tJohnson\tpatricia.johnson@sakilacustomer.org\t6\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n*/\n\n\nCREATE TABLE film (\n\tfilm_id SERIAL NOT NULL, \n\ttitle VARCHAR(255) NOT NULL, \n\tdescription TEXT, \n\trelease_year INTEGER, \n\tlanguage_id SMALLINT NOT NULL, \n\trental_duration SMALLINT DEFAULT 3 NOT NULL, \n\trental_rate NUMERIC(4, 2) DEFAULT 4.99 NOT NULL, \n\tlength SMALLINT, \n\treplacement_cost NUMERIC(5, 2) DEFAULT 19.99 NOT NULL, \n\trating mpaa_ ...
#   "stop": [
#     "\nSQLResult:"
#   ]
# }
# [llm/start] [1:chain:SQLDatabaseChain > 2:chain:LLMChain > 3:llm:Clarifai] Entering LLM run with input:
# {
#   "prompts": [
#     "You are a PostgreSQL expert. Given an input question, first create a syntactically correct PostgreSQL query to run, then look at the results of the query and return the answer to the input question.\nUnless the user specifies in the question a specific number of examples to obtain, query for at most 5 results using the LIMIT clause as per PostgreSQL. You can order the results to return the most informative data in the database.\nNever query for all columns from a table. You must query only the columns that are needed to answer the question. Wrap each column name in double quotes (\") to denote them as delimited identifiers.\nPay attention to use only the column names you can see in the tables below. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which table.\nPay attention to use CURRENT_DATE function to get the current date, if the question involves \"today\".\n\nUse the following format:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use the following tables:\n\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update ...
#   ]
# }
# [llm/end] [1:chain:SQLDatabaseChain > 2:chain:LLMChain > 3:llm:Clarifai] [6.81s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "SELECT \"first_name\", \"email\" FROM customer LIMIT 5;\n",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/end] [1:chain:SQLDatabaseChain > 2:chain:LLMChain] [6.81s] Exiting Chain run with output:
# {
#   "text": "SELECT \"first_name\", \"email\" FROM customer LIMIT 5;\n"
# }
# [chain/start] [1:chain:SQLDatabaseChain > 4:chain:LLMChain] Entering Chain run with input:
# {
#   "input": "\nYou are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:\n\n1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.\n2)Execute the query and return the results to answer the input question.\n3)Ensure that the query selects only the required columns from the relevant tables.\n5)Utilize only the column names present in the provided tables.\n6)Avoid querying for columns that do not exist.\n7) If the question involves \"today\", use the CURRENT_DATE function to get the current date.\n8) Order the results to return the most informative data in the database.\n9) Dont add code blocks for sql query\n10) Please adhere to the following format while giving outputs:\n\nImportant! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error\n\nSQL Query code  with final answer from database\n\ngive me the first name  and emails of customers?\n\nSQLQuery:SELECT \"first_name\", \"email\" FROM customer LIMIT 5;\nSQLResult: [('Jared', 'jared.ely@sakilacustomer.org'), ('Mary', 'mary.smith@sakilacustomer.org'), ('Patricia', 'patricia.johnson@sakilacustomer.org'), ('Linda', 'linda.williams@sakilacustomer.org'), ('Barbara', 'barbara.jones@sakilacustomer.org')]\nAnswer:",
#   "top_k": "5",
#   "dialect": "postgresql",
#   "table_info": "\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now(), \n\tactive INTEGER, \n\tCONSTRAINT customer_pkey PRIMARY KEY (customer_id), \n\tCONSTRAINT customer_address_id_fkey FOREIGN KEY(address_id) REFERENCES address (address_id) ON DELETE RESTRICT ON UPDATE CASCADE\n)\n\n/*\n3 rows from customer table:\ncustomer_id\tstore_id\tfirst_name\tlast_name\temail\taddress_id\tactivebool\tcreate_date\tlast_update\tactive\n524\t1\tJared\tEly\tjared.ely@sakilacustomer.org\t530\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n1\t1\tMary\tSmith\tmary.smith@sakilacustomer.org\t5\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n2\t1\tPatricia\tJohnson\tpatricia.johnson@sakilacustomer.org\t6\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n*/\n\n\nCREATE TABLE film (\n\tfilm_id SERIAL NOT NULL, \n\ttitle VARCHAR(255) NOT NULL, \n\tdescription TEXT, \n\trelease_year INTEGER, \n\tlanguage_id SMALLINT NOT NULL, \n\trental_duration SMALLINT DEFAULT 3 NOT NULL, \n\trental_rate NUMERIC(4, 2) DEFAULT 4.99 NOT NULL, \n\tlength SMALLINT, \n\treplacement_cost NUMERIC(5, 2) DEFAULT 19.99 NOT NULL, \n\trating mpaa_ ...
#   "stop": [
#     "\nSQLResult:"
#   ]
# }
# [llm/start] [1:chain:SQLDatabaseChain > 4:chain:LLMChain > 5:llm:Clarifai] Entering LLM run with input:
# {
#   "prompts": [
#     "You are a PostgreSQL expert. Given an input question, first create a syntactically correct PostgreSQL query to run, then look at the results of the query and return the answer to the input question.\nUnless the user specifies in the question a specific number of examples to obtain, query for at most 5 results using the LIMIT clause as per PostgreSQL. You can order the results to return the most informative data in the database.\nNever query for all columns from a table. You must query only the columns that are needed to answer the question. Wrap each column name in double quotes (\") to denote them as delimited identifiers.\nPay attention to use only the column names you can see in the tables below. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which table.\nPay attention to use CURRENT_DATE function to get the current date, if the question involves \"today\".\n\nUse the following format:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use the following tables:\n\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update ...
#   ]
# }
# [llm/end] [1:chain:SQLDatabaseChain > 4:chain:LLMChain > 5:llm:Clarifai] [7.91s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The first names and emails of customers are as follows:\n\n1. Jared - jared.ely@sakilacustomer.org\n2. Mary - mary.smith@sakilacustomer.org\n3. Patricia - patricia.johnson@sakilacustomer.org\n4. Linda - linda.williams@sakilacustomer.org\n5. Barbara - barbara.jones@sakilacustomer.org",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/end] [1:chain:SQLDatabaseChain > 4:chain:LLMChain] [7.92s] Exiting Chain run with output:
# {
#   "text": "The first names and emails of customers are as follows:\n\n1. Jared - jared.ely@sakilacustomer.org\n2. Mary - mary.smith@sakilacustomer.org\n3. Patricia - patricia.johnson@sakilacustomer.org\n4. Linda - linda.williams@sakilacustomer.org\n5. Barbara - barbara.jones@sakilacustomer.org"
# }
# [chain/end] [1:chain:SQLDatabaseChain] [14.75s] Exiting Chain run with output:
# {
#   "result": "The first names and emails of customers are as follows:\n\n1. Jared - jared.ely@sakilacustomer.org\n2. Mary - mary.smith@sakilacustomer.org\n3. Patricia - patricia.johnson@sakilacustomer.org\n4. Linda - linda.williams@sakilacustomer.org\n5. Barbara - barbara.jones@sakilacustomer.org"
# }

# %%
question = "give me the details of Linda Williams?" 
# use db_chain.run(question) instead if you don't have a prompt
res=db_chain.run(PROMPT.format(question=question))
# Out:
# [chain/start] [1:chain:SQLDatabaseChain] Entering Chain run with input:
# {
#   "query": "\nYou are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:\n\n1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.\n2)Execute the query and return the results to answer the input question.\n3)Ensure that the query selects only the required columns from the relevant tables.\n5)Utilize only the column names present in the provided tables.\n6)Avoid querying for columns that do not exist.\n7) If the question involves \"today\", use the CURRENT_DATE function to get the current date.\n8) Order the results to return the most informative data in the database.\n9) Dont add code blocks for sql query\n10) Please adhere to the following format while giving outputs:\n\nImportant! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error\n\nSQL Query code  with final answer from database\n\ngive me the details of Linda Williams?\n"
# }
# [chain/start] [1:chain:SQLDatabaseChain > 2:chain:LLMChain] Entering Chain run with input:
# {
#   "input": "\nYou are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:\n\n1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.\n2)Execute the query and return the results to answer the input question.\n3)Ensure that the query selects only the required columns from the relevant tables.\n5)Utilize only the column names present in the provided tables.\n6)Avoid querying for columns that do not exist.\n7) If the question involves \"today\", use the CURRENT_DATE function to get the current date.\n8) Order the results to return the most informative data in the database.\n9) Dont add code blocks for sql query\n10) Please adhere to the following format while giving outputs:\n\nImportant! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error\n\nSQL Query code  with final answer from database\n\ngive me the details of Linda Williams?\n\nSQLQuery:",
#   "top_k": "5",
#   "dialect": "postgresql",
#   "table_info": "\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now(), \n\tactive INTEGER, \n\tCONSTRAINT customer_pkey PRIMARY KEY (customer_id), \n\tCONSTRAINT customer_address_id_fkey FOREIGN KEY(address_id) REFERENCES address (address_id) ON DELETE RESTRICT ON UPDATE CASCADE\n)\n\n/*\n3 rows from customer table:\ncustomer_id\tstore_id\tfirst_name\tlast_name\temail\taddress_id\tactivebool\tcreate_date\tlast_update\tactive\n524\t1\tJared\tEly\tjared.ely@sakilacustomer.org\t530\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n1\t1\tMary\tSmith\tmary.smith@sakilacustomer.org\t5\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n2\t1\tPatricia\tJohnson\tpatricia.johnson@sakilacustomer.org\t6\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n*/\n\n\nCREATE TABLE film (\n\tfilm_id SERIAL NOT NULL, \n\ttitle VARCHAR(255) NOT NULL, \n\tdescription TEXT, \n\trelease_year INTEGER, \n\tlanguage_id SMALLINT NOT NULL, \n\trental_duration SMALLINT DEFAULT 3 NOT NULL, \n\trental_rate NUMERIC(4, 2) DEFAULT 4.99 NOT NULL, \n\tlength SMALLINT, \n\treplacement_cost NUMERIC(5, 2) DEFAULT 19.99 NOT NULL, \n\trating mpaa_ ...
#   "stop": [
#     "\nSQLResult:"
#   ]
# }
# [llm/start] [1:chain:SQLDatabaseChain > 2:chain:LLMChain > 3:llm:Clarifai] Entering LLM run with input:
# {
#   "prompts": [
#     "You are a PostgreSQL expert. Given an input question, first create a syntactically correct PostgreSQL query to run, then look at the results of the query and return the answer to the input question.\nUnless the user specifies in the question a specific number of examples to obtain, query for at most 5 results using the LIMIT clause as per PostgreSQL. You can order the results to return the most informative data in the database.\nNever query for all columns from a table. You must query only the columns that are needed to answer the question. Wrap each column name in double quotes (\") to denote them as delimited identifiers.\nPay attention to use only the column names you can see in the tables below. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which table.\nPay attention to use CURRENT_DATE function to get the current date, if the question involves \"today\".\n\nUse the following format:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use the following tables:\n\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update ...
#   ]
# }
# [llm/end] [1:chain:SQLDatabaseChain > 2:chain:LLMChain > 3:llm:Clarifai] [7.47s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "SQLQuery: SELECT \"customer_id\", \"store_id\", \"first_name\", \"last_name\", \"email\", \"address_id\", \"activebool\", \"create_date\", \"last_update\", \"active\" FROM \"customer\" WHERE \"first_name\" = 'Linda' AND \"last_name\" = 'Williams' LIMIT 5;\n",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/end] [1:chain:SQLDatabaseChain > 2:chain:LLMChain] [7.47s] Exiting Chain run with output:
# {
#   "text": "SQLQuery: SELECT \"customer_id\", \"store_id\", \"first_name\", \"last_name\", \"email\", \"address_id\", \"activebool\", \"create_date\", \"last_update\", \"active\" FROM \"customer\" WHERE \"first_name\" = 'Linda' AND \"last_name\" = 'Williams' LIMIT 5;\n"
# }
# [chain/start] [1:chain:SQLDatabaseChain > 4:chain:LLMChain] Entering Chain run with input:
# {
#   "input": "\nYou are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:\n\n1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.\n2)Execute the query and return the results to answer the input question.\n3)Ensure that the query selects only the required columns from the relevant tables.\n5)Utilize only the column names present in the provided tables.\n6)Avoid querying for columns that do not exist.\n7) If the question involves \"today\", use the CURRENT_DATE function to get the current date.\n8) Order the results to return the most informative data in the database.\n9) Dont add code blocks for sql query\n10) Please adhere to the following format while giving outputs:\n\nImportant! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error\n\nSQL Query code  with final answer from database\n\ngive me the details of Linda Williams?\n\nSQLQuery:SELECT \"customer_id\", \"store_id\", \"first_name\", \"last_name\", \"email\", \"address_id\", \"activebool\", \"create_date\", \"last_update\", \"active\" FROM \"customer\" WHERE \"first_name\" = 'Linda' AND \"last_name\" = 'Williams' LIMIT 5;\nSQLResult: [(3, 1, 'Linda', 'Williams', 'linda.williams@sakilacustomer.org', 7, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)]\nAnswer:",
#   "top_k": "5",
#   "dialect": "postgresql",
#   "table_info": "\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now(), \n\tactive INTEGER, \n\tCONSTRAINT customer_pkey PRIMARY KEY (customer_id), \n\tCONSTRAINT customer_address_id_fkey FOREIGN KEY(address_id) REFERENCES address (address_id) ON DELETE RESTRICT ON UPDATE CASCADE\n)\n\n/*\n3 rows from customer table:\ncustomer_id\tstore_id\tfirst_name\tlast_name\temail\taddress_id\tactivebool\tcreate_date\tlast_update\tactive\n524\t1\tJared\tEly\tjared.ely@sakilacustomer.org\t530\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n1\t1\tMary\tSmith\tmary.smith@sakilacustomer.org\t5\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n2\t1\tPatricia\tJohnson\tpatricia.johnson@sakilacustomer.org\t6\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n*/\n\n\nCREATE TABLE film (\n\tfilm_id SERIAL NOT NULL, \n\ttitle VARCHAR(255) NOT NULL, \n\tdescription TEXT, \n\trelease_year INTEGER, \n\tlanguage_id SMALLINT NOT NULL, \n\trental_duration SMALLINT DEFAULT 3 NOT NULL, \n\trental_rate NUMERIC(4, 2) DEFAULT 4.99 NOT NULL, \n\tlength SMALLINT, \n\treplacement_cost NUMERIC(5, 2) DEFAULT 19.99 NOT NULL, \n\trating mpaa_ ...
#   "stop": [
#     "\nSQLResult:"
#   ]
# }
# [llm/start] [1:chain:SQLDatabaseChain > 4:chain:LLMChain > 5:llm:Clarifai] Entering LLM run with input:
# {
#   "prompts": [
#     "You are a PostgreSQL expert. Given an input question, first create a syntactically correct PostgreSQL query to run, then look at the results of the query and return the answer to the input question.\nUnless the user specifies in the question a specific number of examples to obtain, query for at most 5 results using the LIMIT clause as per PostgreSQL. You can order the results to return the most informative data in the database.\nNever query for all columns from a table. You must query only the columns that are needed to answer the question. Wrap each column name in double quotes (\") to denote them as delimited identifiers.\nPay attention to use only the column names you can see in the tables below. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which table.\nPay attention to use CURRENT_DATE function to get the current date, if the question involves \"today\".\n\nUse the following format:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use the following tables:\n\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update ...
#   ]
# }
# [llm/end] [1:chain:SQLDatabaseChain > 4:chain:LLMChain > 5:llm:Clarifai] [4.86s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Customer ID: 3, Store ID: 1, First Name: Linda, Last Name: Williams, Email: linda.williams@sakilacustomer.org, Address ID: 7, Active: True, Create Date: 2006-02-14, Last Update: 2013-05-26 14:49:45.738, Active Status: 1",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/end] [1:chain:SQLDatabaseChain > 4:chain:LLMChain] [4.86s] Exiting Chain run with output:
# {
#   "text": "Customer ID: 3, Store ID: 1, First Name: Linda, Last Name: Williams, Email: linda.williams@sakilacustomer.org, Address ID: 7, Active: True, Create Date: 2006-02-14, Last Update: 2013-05-26 14:49:45.738, Active Status: 1"
# }
# [chain/end] [1:chain:SQLDatabaseChain] [12.37s] Exiting Chain run with output:
# {
#   "result": "Customer ID: 3, Store ID: 1, First Name: Linda, Last Name: Williams, Email: linda.williams@sakilacustomer.org, Address ID: 7, Active: True, Create Date: 2006-02-14, Last Update: 2013-05-26 14:49:45.738, Active Status: 1"
# }

# %% [markdown]
# The following question makes the LLM use multiple tables for running queries,

# %%
question = "give me the name and payment made by top 5 customers?" 
# use db_chain.run(question) instead if you don't have a prompt
result=db_chain.run(PROMPT.format(question=question))
# Out:
# [chain/start] [1:chain:SQLDatabaseChain] Entering Chain run with input:
# {
#   "query": "\nYou are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:\n\n1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.\n2)Execute the query and return the results to answer the input question.\n3)Ensure that the query selects only the required columns from the relevant tables.\n5)Utilize only the column names present in the provided tables.\n6)Avoid querying for columns that do not exist.\n7) If the question involves \"today\", use the CURRENT_DATE function to get the current date.\n8) Order the results to return the most informative data in the database.\n9) Dont add code blocks for sql query\n10) Please adhere to the following format while giving outputs:\n\nImportant! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error\n\nSQL Query code  with final answer from database\n\ngive me the name and payment made by top 5 customers?\n"
# }
# [chain/start] [1:chain:SQLDatabaseChain > 2:chain:LLMChain] Entering Chain run with input:
# {
#   "input": "\nYou are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:\n\n1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.\n2)Execute the query and return the results to answer the input question.\n3)Ensure that the query selects only the required columns from the relevant tables.\n5)Utilize only the column names present in the provided tables.\n6)Avoid querying for columns that do not exist.\n7) If the question involves \"today\", use the CURRENT_DATE function to get the current date.\n8) Order the results to return the most informative data in the database.\n9) Dont add code blocks for sql query\n10) Please adhere to the following format while giving outputs:\n\nImportant! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error\n\nSQL Query code  with final answer from database\n\ngive me the name and payment made by top 5 customers?\n\nSQLQuery:",
#   "top_k": "5",
#   "dialect": "postgresql",
#   "table_info": "\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now(), \n\tactive INTEGER, \n\tCONSTRAINT customer_pkey PRIMARY KEY (customer_id), \n\tCONSTRAINT customer_address_id_fkey FOREIGN KEY(address_id) REFERENCES address (address_id) ON DELETE RESTRICT ON UPDATE CASCADE\n)\n\n/*\n3 rows from customer table:\ncustomer_id\tstore_id\tfirst_name\tlast_name\temail\taddress_id\tactivebool\tcreate_date\tlast_update\tactive\n524\t1\tJared\tEly\tjared.ely@sakilacustomer.org\t530\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n1\t1\tMary\tSmith\tmary.smith@sakilacustomer.org\t5\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n2\t1\tPatricia\tJohnson\tpatricia.johnson@sakilacustomer.org\t6\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n*/\n\n\nCREATE TABLE film (\n\tfilm_id SERIAL NOT NULL, \n\ttitle VARCHAR(255) NOT NULL, \n\tdescription TEXT, \n\trelease_year INTEGER, \n\tlanguage_id SMALLINT NOT NULL, \n\trental_duration SMALLINT DEFAULT 3 NOT NULL, \n\trental_rate NUMERIC(4, 2) DEFAULT 4.99 NOT NULL, \n\tlength SMALLINT, \n\treplacement_cost NUMERIC(5, 2) DEFAULT 19.99 NOT NULL, \n\trating mpaa_ ...
#   "stop": [
#     "\nSQLResult:"
#   ]
# }
# [llm/start] [1:chain:SQLDatabaseChain > 2:chain:LLMChain > 3:llm:Clarifai] Entering LLM run with input:
# {
#   "prompts": [
#     "You are a PostgreSQL expert. Given an input question, first create a syntactically correct PostgreSQL query to run, then look at the results of the query and return the answer to the input question.\nUnless the user specifies in the question a specific number of examples to obtain, query for at most 5 results using the LIMIT clause as per PostgreSQL. You can order the results to return the most informative data in the database.\nNever query for all columns from a table. You must query only the columns that are needed to answer the question. Wrap each column name in double quotes (\") to denote them as delimited identifiers.\nPay attention to use only the column names you can see in the tables below. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which table.\nPay attention to use CURRENT_DATE function to get the current date, if the question involves \"today\".\n\nUse the following format:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use the following tables:\n\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update ...
#   ]
# }
# [llm/end] [1:chain:SQLDatabaseChain > 2:chain:LLMChain > 3:llm:Clarifai] [7.19s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "SQLQuery: \nSELECT c.first_name, c.last_name, SUM(p.amount) AS total_payment\nFROM customer c\nJOIN payment p ON c.customer_id = p.customer_id\nGROUP BY c.customer_id\nORDER BY total_payment DESC\nLIMIT 5;\n",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/end] [1:chain:SQLDatabaseChain > 2:chain:LLMChain] [7.19s] Exiting Chain run with output:
# {
#   "text": "SQLQuery: \nSELECT c.first_name, c.last_name, SUM(p.amount) AS total_payment\nFROM customer c\nJOIN payment p ON c.customer_id = p.customer_id\nGROUP BY c.customer_id\nORDER BY total_payment DESC\nLIMIT 5;\n"
# }
# [chain/start] [1:chain:SQLDatabaseChain > 4:chain:LLMChain] Entering Chain run with input:
# {
#   "input": "\nYou are a PostgreSQL expert tasked with answering questions based on a database. Given an input question, your task is to:\n\n1) Create a syntactically correct PostgreSQL query to retrieve the necessary information.\n2)Execute the query and return the results to answer the input question.\n3)Ensure that the query selects only the required columns from the relevant tables.\n5)Utilize only the column names present in the provided tables.\n6)Avoid querying for columns that do not exist.\n7) If the question involves \"today\", use the CURRENT_DATE function to get the current date.\n8) Order the results to return the most informative data in the database.\n9) Dont add code blocks for sql query\n10) Please adhere to the following format while giving outputs:\n\nImportant! You should provide the postgres code along with query output from database for the following question, do not add backticks or codeblock while giving sql query as it might lead to error\n\nSQL Query code  with final answer from database\n\ngive me the name and payment made by top 5 customers?\n\nSQLQuery:SELECT c.first_name, c.last_name, SUM(p.amount) AS total_payment\nFROM customer c\nJOIN payment p ON c.customer_id = p.customer_id\nGROUP BY c.customer_id\nORDER BY total_payment DESC\nLIMIT 5;\nSQLResult: [('Eleanor', 'Hunt', Decimal('211.55')), ('Karl', 'Seal', Decimal('208.58')), ('Marion', 'Snyder', Decimal('194.61')), ('Rhonda', 'Kennedy', Decimal('191.62')), ('Clara', 'Shaw', Decimal('189.60'))]\nAnswer:",
#   "top_k": "5",
#   "dialect": "postgresql",
#   "table_info": "\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now(), \n\tactive INTEGER, \n\tCONSTRAINT customer_pkey PRIMARY KEY (customer_id), \n\tCONSTRAINT customer_address_id_fkey FOREIGN KEY(address_id) REFERENCES address (address_id) ON DELETE RESTRICT ON UPDATE CASCADE\n)\n\n/*\n3 rows from customer table:\ncustomer_id\tstore_id\tfirst_name\tlast_name\temail\taddress_id\tactivebool\tcreate_date\tlast_update\tactive\n524\t1\tJared\tEly\tjared.ely@sakilacustomer.org\t530\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n1\t1\tMary\tSmith\tmary.smith@sakilacustomer.org\t5\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n2\t1\tPatricia\tJohnson\tpatricia.johnson@sakilacustomer.org\t6\tTrue\t2006-02-14\t2013-05-26 14:49:45.738000\t1\n*/\n\n\nCREATE TABLE film (\n\tfilm_id SERIAL NOT NULL, \n\ttitle VARCHAR(255) NOT NULL, \n\tdescription TEXT, \n\trelease_year INTEGER, \n\tlanguage_id SMALLINT NOT NULL, \n\trental_duration SMALLINT DEFAULT 3 NOT NULL, \n\trental_rate NUMERIC(4, 2) DEFAULT 4.99 NOT NULL, \n\tlength SMALLINT, \n\treplacement_cost NUMERIC(5, 2) DEFAULT 19.99 NOT NULL, \n\trating mpaa_ ...
#   "stop": [
#     "\nSQLResult:"
#   ]
# }
# [llm/start] [1:chain:SQLDatabaseChain > 4:chain:LLMChain > 5:llm:Clarifai] Entering LLM run with input:
# {
#   "prompts": [
#     "You are a PostgreSQL expert. Given an input question, first create a syntactically correct PostgreSQL query to run, then look at the results of the query and return the answer to the input question.\nUnless the user specifies in the question a specific number of examples to obtain, query for at most 5 results using the LIMIT clause as per PostgreSQL. You can order the results to return the most informative data in the database.\nNever query for all columns from a table. You must query only the columns that are needed to answer the question. Wrap each column name in double quotes (\") to denote them as delimited identifiers.\nPay attention to use only the column names you can see in the tables below. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which table.\nPay attention to use CURRENT_DATE function to get the current date, if the question involves \"today\".\n\nUse the following format:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use the following tables:\n\nCREATE TABLE actor (\n\tactor_id SERIAL NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT actor_pkey PRIMARY KEY (actor_id)\n)\n\n/*\n3 rows from actor table:\nactor_id\tfirst_name\tlast_name\tlast_update\n1\tPenelope\tGuiness\t2013-05-26 14:47:57.620000\n2\tNick\tWahlberg\t2013-05-26 14:47:57.620000\n3\tEd\tChase\t2013-05-26 14:47:57.620000\n*/\n\n\nCREATE TABLE address (\n\taddress_id SERIAL NOT NULL, \n\taddress VARCHAR(50) NOT NULL, \n\taddress2 VARCHAR(50), \n\tdistrict VARCHAR(20) NOT NULL, \n\tcity_id SMALLINT NOT NULL, \n\tpostal_code VARCHAR(10), \n\tphone VARCHAR(20) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT address_pkey PRIMARY KEY (address_id), \n\tCONSTRAINT fk_address_city FOREIGN KEY(city_id) REFERENCES city (city_id)\n)\n\n/*\n3 rows from address table:\naddress_id\taddress\taddress2\tdistrict\tcity_id\tpostal_code\tphone\tlast_update\n1\t47 MySakila Drive\tNone\tAlberta\t300\t\t\t2006-02-15 09:45:30\n2\t28 MySQL Boulevard\tNone\tQLD\t576\t\t\t2006-02-15 09:45:30\n3\t23 Workhaven Lane\tNone\tAlberta\t300\t\t14033335568\t2006-02-15 09:45:30\n*/\n\n\nCREATE TABLE category (\n\tcategory_id SERIAL NOT NULL, \n\tname VARCHAR(25) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT category_pkey PRIMARY KEY (category_id)\n)\n\n/*\n3 rows from category table:\ncategory_id\tname\tlast_update\n1\tAction\t2006-02-15 09:46:27\n2\tAnimation\t2006-02-15 09:46:27\n3\tChildren\t2006-02-15 09:46:27\n*/\n\n\nCREATE TABLE city (\n\tcity_id SERIAL NOT NULL, \n\tcity VARCHAR(50) NOT NULL, \n\tcountry_id SMALLINT NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT city_pkey PRIMARY KEY (city_id), \n\tCONSTRAINT fk_city FOREIGN KEY(country_id) REFERENCES country (country_id)\n)\n\n/*\n3 rows from city table:\ncity_id\tcity\tcountry_id\tlast_update\n1\tA Corua (La Corua)\t87\t2006-02-15 09:45:25\n2\tAbha\t82\t2006-02-15 09:45:25\n3\tAbu Dhabi\t101\t2006-02-15 09:45:25\n*/\n\n\nCREATE TABLE country (\n\tcountry_id SERIAL NOT NULL, \n\tcountry VARCHAR(50) NOT NULL, \n\tlast_update TIMESTAMP WITHOUT TIME ZONE DEFAULT now() NOT NULL, \n\tCONSTRAINT country_pkey PRIMARY KEY (country_id)\n)\n\n/*\n3 rows from country table:\ncountry_id\tcountry\tlast_update\n1\tAfghanistan\t2006-02-15 09:44:00\n2\tAlgeria\t2006-02-15 09:44:00\n3\tAmerican Samoa\t2006-02-15 09:44:00\n*/\n\n\nCREATE TABLE customer (\n\tcustomer_id SERIAL NOT NULL, \n\tstore_id SMALLINT NOT NULL, \n\tfirst_name VARCHAR(45) NOT NULL, \n\tlast_name VARCHAR(45) NOT NULL, \n\temail VARCHAR(50), \n\taddress_id SMALLINT NOT NULL, \n\tactivebool BOOLEAN DEFAULT true NOT NULL, \n\tcreate_date DATE DEFAULT ('now'::text)::date NOT NULL, \n\tlast_update ...
#   ]
# }
# [llm/end] [1:chain:SQLDatabaseChain > 4:chain:LLMChain > 5:llm:Clarifai] [6.61s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The top 5 customers by payment made are:\n\n1. Eleanor Hunt with a total payment of $211.55\n2. Karl Seal with a total payment of $208.58\n3. Marion Snyder with a total payment of $194.61\n4. Rhonda Kennedy with a total payment of $191.62\n5. Clara Shaw with a total payment of $189.60",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/end] [1:chain:SQLDatabaseChain > 4:chain:LLMChain] [6.61s] Exiting Chain run with output:
# {
#   "text": "The top 5 customers by payment made are:\n\n1. Eleanor Hunt with a total payment of $211.55\n2. Karl Seal with a total payment of $208.58\n3. Marion Snyder with a total payment of $194.61\n4. Rhonda Kennedy with a total payment of $191.62\n5. Clara Shaw with a total payment of $189.60"
# }
# [chain/end] [1:chain:SQLDatabaseChain] [13.90s] Exiting Chain run with output:
# {
#   "result": "The top 5 customers by payment made are:\n\n1. Eleanor Hunt with a total payment of $211.55\n2. Karl Seal with a total payment of $208.58\n3. Marion Snyder with a total payment of $194.61\n4. Rhonda Kennedy with a total payment of $191.62\n5. Clara Shaw with a total payment of $189.60"
# }

# %%
# displaying the results in readable format
answer=result.split('\n')
for i in answer:
    print(i,'\n')
# Out:
# The top 5 customers by payment made are:
#
#
#
# 1. Eleanor Hunt with a total payment of $211.55
#
# 2. Karl Seal with a total payment of $208.58
#
# 3. Marion Snyder with a total payment of $194.61
#
# 4. Rhonda Kennedy with a total payment of $191.62
#
# 5. Clara Shaw with a total payment of $189.60
